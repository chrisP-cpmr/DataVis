# %%
import csv
import pandas as pd

# %%
data = pd.read_csv('Data.csv')

# %%
data[:20]
# Out:
#     m49_code          country  \
# 0        116         Cambodia
# 1        116         Cambodia
# 2        116         Cambodia
# 3        116         Cambodia
# 4        116         Cambodia
# 5        116         Cambodia
# 6        116         Cambodia
# 7        116         Cambodia
# 8        120         Cameroon
# 9        143     Central Asia
# 10       143     Central Asia
# 11       143     Central Asia
# 12       143     Central Asia
# 13       143     Central Asia
# 14       145     Western Asia
# 15       145     Western Asia
# 16       145     Western Asia
# 17       145     Western Asia
# 18       145     Western Asia
# 19        15  Northern Africa
#
#                                                region  cpc_code  \
# 0   Kandal Province, and wholesalers and retailers...    1234.0
# 1   Kandal Province, and wholesalers and retailers...    1234.0
# 2   Kandal Province, and wholesalers and retailers...    1234.0
# ...

# %%
data.describe()
# Out:
#           m49_code      cpc_code         year  loss_percentage
# count  1898.000000   1898.000000  1898.000000      1898.000000
# mean    557.868282   2128.771697  2011.750790        11.601528
# std     293.362129   4048.321171     2.831512        11.022011
# min      15.000000   1211.000000  2007.000000         0.000000
# 25%     332.000000   1234.000000  2009.250000         4.500000
# 50%     635.000000   1311.000000  2011.000000         8.000000
# 75%     840.000000   1323.000000  2014.000000        15.000000
# max     862.000000  21439.040000  2017.000000        65.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1898 entries, 0 to 1897
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   m49_code                1898 non-null   int64
#  1   country                 1898 non-null   object
#  2   region                  118 non-null    object
#  3   cpc_code                1898 non-null   float64
#  4   commodity               1898 non-null   object
#  5   year                    1898 non-null   int64
#  6   loss_percentage         1898 non-null   float64
#  7   food_supply_stage       1885 non-null   object
#  8   treatment               219 non-null    object
#  9   cause_of_loss           338 non-null    object
#  10  sample_size             504 non-null    object
#  11  method_data_collection  1802 non-null   object
#  12  reference               1205 non-null   object
#  13  url                     1220 non-null   object
# ...

# %%
data = data.drop(["m49_code", "region", "cpc_code", "treatment", "cause_of_loss", "sample_size", 
                  "method_data_collection", "reference", "url","notes"], 
                 axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1898 entries, 0 to 1897
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   country            1898 non-null   object
#  1   commodity          1898 non-null   object
#  2   year               1898 non-null   int64
#  3   loss_percentage    1898 non-null   float64
#  4   food_supply_stage  1885 non-null   object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 74.3+ KB

# %%
data.head()
# Out:
#     country                  commodity  year  loss_percentage  \
# 0  Cambodia                   Tomatoes  2013              3.5
# 1  Cambodia                   Tomatoes  2013             12.5
# 2  Cambodia                   Tomatoes  2013              3.5
# 3  Cambodia                   Tomatoes  2013              3.5
# 4  Cambodia  Cauliflowers and broccoli  2008             16.4
#
#     food_supply_stage
# 0              Trader
# 1                Farm
# 2              Retail
# 3           Wholesale
# 4  Whole supply chain

# %%
data.to_excel("Data_clean_v2.xlsx")
data.to_csv("Data_clean_v2.csv", index=False)
